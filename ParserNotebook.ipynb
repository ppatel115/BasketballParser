# %%
filepath = 'sample_input.txt'
with open(filepath) as fp:
    line = fp.readline()
    while line:
        print line
        line = fp.readline()
# Out:
# Kyle Washington with a turnover - Bad Pass 0 0 19:15
#
# Jarron Cumberland blocks a Keith Stone layup. 0 0 19:15
#
# Gators with an offensive rebound. 0 0 19:14
#
# Gators with a turnover: Shot Clock Turnover 0 0 18:54
#
# Offensive foul committed by Kyle Washington. 0 0 18:54
#
# Kyle Washington is charged with a turnover due to a foul. 0 0 18:35
#
# Shooting foul committed by Gary Clark. 0 0 18:35
#
# Keith Stone makes free throw 1 of 2. 1 0 18:35
#
# Keith Stone makes free throw 2 of 2. 2 0 18:15
#
# Kyle Washington makes a jump shot from 10 feet out. 2 2 17:56
#
# Jalen Hudson with a turnover - Traveling 2 2 17:37
#
# Kyle Washington makes a 3-point jump shot from 25 feet out. Jacob Evans III with the assist. 2 5 17:16
#
# Egor Koulechov misses a layup. 2 5 17:16
#
# Gary Clark with a defensive rebound. 2 5 16:54
#
# Jacob Evans III misses a 3-point jump shot from 24 feet out. 2 5 16:54
#
# Jarron Cumberland with an offensive rebound. 2 5 16:47
#
# ...
